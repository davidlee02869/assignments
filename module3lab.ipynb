# %%
class vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

class automobile(vehicle):
    def __init__(self, vehicle_type, year, make, model, doors, roof):
        super().__init__(vehicle_type)
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof
    def __str__(self):
        return (f"Vehicle type: {self.vehicle_type}\n"
                f"Year: {self.year}\n"
                f"Make: {self.make}\n"
                f"Model: {self.model}\n"
                f"Number of doors: {self.doors}\n"
                f"Type of roof: {self.roof}")
car = automobile(input("Vehicle type: "), input("Year: "), input("Make: "), input("Model: "), input("Doors: "), input("Roof: "))
print(car)
# Out:
# Vehicle type:  car
# Year:  2012
# Make:  nissan
# Model:  altima
# Doors:  4
# Roof:  sunroof
# Vehicle type: car
# Year: 2012
# Make: nissan
# Model: altima
# Number of doors: 4
# Type of roof: sunroof
